# %%
num = int(input("Enter จำนวนนับนะจ๊ะ: "))
num1 = num
N =[]
x = True
def num2listN():
    N.clear()
    for i in str(num):
        N.append(int(i))
    # print(N)

def SUM2num():
    global num
    for i in range(0,len(N)):
        # print("i:",i)
        NUM=N[0]**2
        # print("..",NUM)
        N.append(NUM)
        # print(N)
        N.pop(0)
        # print(N)
    num=sum(N)
    # print("newN",N)
    # print("newnum",num)

while x:
    num2listN()
    SUM2num()
    if len(N) == 1:
        x = False

# print("ending len",len(N))
# print("ending num",num)
if num ==1:
    print(num1,"is happy number :D")
elif num!=1:
    print(num1,"is unhappy number ;C")
# Out:
# 600 is unhappy number ;C

# %%
n = int(input("Enter จำนวนนับนะจ๊ะ: "))
nn = str(n**(1/2))
print(nn)
listnn=nn.split(".")
if listnn[1]== "0":
    print(n,"is perfect number")
else:
    print(n,"is not perfect number")
# Out:
# 8.48528137423857
# 72 is not perfect number
