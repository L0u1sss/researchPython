# %%
num = int(input("Enter number: "))
num1 = num
N =[]
def num2listN():
    N.clear()
    for i in str(num):
        N.append(int(i))
    print(N)

def SUM2num():
    global num
    for i in range(0,len(N)):
        # print("i:",i)
        NUM=N[0]**2
        # print("..",NUM)
        N.append(NUM)
        # print(N)
        N.pop(0)
        # print(N)
    num=sum(N)
    print("newN",N)
    print("newnum",num)

num2listN()
SUM2num()
num2listN()
SUM2num()
num2listN()
SUM2num()
num2listN()
SUM2num()
num2listN()
SUM2num()

# while len(N)>1:

# for i in N:
#     print("i :",i)
#     I=i**2
#     print("i^2 :",I)
#     NN.append(I)
#     print(NN)
#     N.clear()
# sumN=sum(NN)
print("ending len",len(N))
print("ending num",num)
if num ==1:
    print(num1,"is happy number")
elif num!=1:
    print(num1,"is not happy number")
# Out:
# [4, 9]
# newN [16, 81]
# newnum 97
# [9, 7]
# newN [81, 49]
# newnum 130
# [1, 3, 0]
# newN [1, 9, 0]
# newnum 10
# [1, 0]
# newN [1, 0]
# newnum 1
# [1]
# newN [1]
# newnum 1
# ending len 1
# ending num 1
# 49 is happy number
