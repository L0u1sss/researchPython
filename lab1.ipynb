# %% [markdown]
# <p style="margin-top: 0px;
#           margin-bottom: 50px;
#           text-align: center;
#           font-family: sans-serif;
#           font-size: 3rem;
#           letter-spacing: 0.15rem;
#           text-transform: uppercase;
#           color: #fff;
#           text-shadow: -4px 4px #ef3550,
#                -8px 8px #f48fb1,
#                -12px 12px #7e57c2,
#                -16px 16px #2196f3,
#                -20px 20px #26c6da,
#                -24px 24px #43a047,
#                -28px 28px #eeff41,
#                -32px 32px #f9a825,
#                -36px 36px #ff5722;">
#                Happy number
# </p>

# %%
n = int(input("Enter จำนวนนับนะจ๊ะ: "))
num1 = n
N =[]
x = True
def num2listN():
    N.clear()
    for i in str(n):
        N.append(int(i))
    # print(N)

def SUM2num():
    global n
    for i in range(0,len(N)):
        # print("i:",i)
        NUM=N[0]**2
        # print("..",NUM)
        N.append(NUM)
        # print(N)
        N.pop(0)
        # print(N)
    n=sum(N)
    # print("newN",N)
    # print("newnum",num)

while x:
    num2listN()
    SUM2num()
    if len(N) == 1:
        x = False

# print("ending len",len(N))
# print("ending num",num)
if n ==1:
    print(num1,"is happy number :D")
elif n!=1:
    print(num1,"is unhappy number ;C")
# Out:
# 280 is happy number :D

# %% [markdown]
# <p style="margin-top: 0px;
#           margin-bottom: 50px;
#           text-align: center;
#           font-family: sans-serif;
#           font-size: 3rem;
#           letter-spacing: 0.15rem;
#           text-transform: uppercase;
#           color: #fff;
#           text-shadow: -4px 4px #ef3550,
#                -8px 8px #f48fb1,
#                -12px 12px #7e57c2,
#                -16px 16px #2196f3,
#                -20px 20px #26c6da,
#                -24px 24px #43a047,
#                -28px 28px #eeff41,
#                -32px 32px #f9a825,
#                -36px 36px #ff5722;">
#                perfect number
# </p>

# %%
n = int(input("Enter จำนวนนับนะจ๊ะ: "))
nn = str(n**(1/2))
# print(nn)
listnn=nn.split(".")
if listnn[1]== "0":
    print(n,"is perfect number")
else:
    print(n,"is not perfect number")
# Out:
# 8.48528137423857
# 72 is not perfect number

# %%
def findprime(n):
    primelist = []
    if n == 0 or n == 1:
        primelist = []
    else:
        for i in range(2,n+1):
            if all(i%j!=0 for j in range(2,i)):
                primelist.append(i)
    return primelist

# %% [markdown]
# <p style="margin-top: 0px;
#           margin-bottom: 50px;
#           text-align: center;
#           font-family: sans-serif;
#           font-size: 3rem;
#           letter-spacing: 0.15rem;
#           text-transform: uppercase;
#           color: #fff;
#           text-shadow: -4px 4px #ef3550,
#                -8px 8px #f48fb1,
#                -12px 12px #7e57c2,
#                -16px 16px #2196f3,
#                -20px 20px #26c6da,
#                -24px 24px #43a047,
#                -28px 28px #eeff41,
#                -32px 32px #f9a825,
#                -36px 36px #ff5722;">
#                e-odd part
# </p>

# %%
n = int(input("Enter จำนวนนับนะจ๊ะ: "))
e = []
eodd = []
eeven = []
for i in findprime(n):
    ans = n/i
    # print("ผลหาร",ans)
    if n%i == 0:
        # print("ตัวที่หารลง",i)
        e.append(i)
    while ans % i == 0:
        ans = ans/i
        # print("หารในloop",ans)
        e.append(i)

# print(e)
# print(e.count(2))
# print(max(e))
for i in range(2,max(e)+1):
    # print("มี{0}อยู่{1}ตัว".format(i,e.count(i)))
    if e.count(i) != 0 :
        # print("มี{0}อยู่{1}ตัว".format(i,e.count(i)))
        if e.count(i) % 2 != 0:
            odd ="{0}^{1}".format(i,e.count(i))
            # print("e-oodของ {0} คือ {1}".format(n,odd))
            eodd.append(odd)
        if e.count(i) % 2 == 0:
            even = "{0}^{1}".format(i,e.count(i))
            # print("e-even ของ {0} คือ {1}".format(n,even))
            eeven.append(even)

# print(eeven)
# print(eodd)


if eodd != []:
    print("e-odd ของ {0} มี {1}".format(n,eodd))

# if eeven != []:
#     print("e-even ของ {0} มี {1}".format(n,eeven))

if eodd == []:
    print("e-oddของ {0} คือ 1".format(n))

# if eeven == []:
#     print("e-evenของ {0} คือ 1".format(n))
# Out:
# e-odd ของ 600 มี ['2^3', '3^1']

# %% [markdown]
# <p style="margin-top: 0px;
#           margin-bottom: 50px;
#           text-align: center;
#           font-family: sans-serif;
#           font-size: 3rem;
#           letter-spacing: 0.15rem;
#           text-transform: uppercase;
#           color: #fff;
#           text-shadow: -4px 4px #ef3550,
#                -8px 8px #f48fb1,
#                -12px 12px #7e57c2,
#                -16px 16px #2196f3,
#                -20px 20px #26c6da,
#                -24px 24px #43a047,
#                -28px 28px #eeff41,
#                -32px 32px #f9a825,
#                -36px 36px #ff5722;">
#                e-even part
# </p>

# %%
n = int(input("Enter จำนวนนับนะจ๊ะ: "))
e = []
eodd = []
eeven = []
for i in findprime(n):
    ans = n/i
    # print("ผลหาร",ans)
    if n%i == 0:
        # print("ตัวที่หารลง",i)
        e.append(i)
    while ans % i == 0:
        ans = ans/i
        # print("หารในloop",ans)
        e.append(i)

# print(e)
# print(e.count(2))
# print(max(e))
for i in range(2,max(e)+1):
    # print("มี{0}อยู่{1}ตัว".format(i,e.count(i)))
    if e.count(i) != 0 :
        # print("มี{0}อยู่{1}ตัว".format(i,e.count(i)))
        if e.count(i) % 2 != 0:
            odd ="{0}^{1}".format(i,e.count(i))
            # print("e-oodของ {0} คือ {1}".format(n,odd))
            eodd.append(odd)
        if e.count(i) % 2 == 0:
            even = "{0}^{1}".format(i,e.count(i))
            # print("e-even ของ {0} คือ {1}".format(n,even))
            eeven.append(even)

# print(eeven)
# print(eodd)


# if eodd != []:
#     print("e-odd ของ {0} มี {1}".format(n,eodd))

if eeven != []:
    print("e-even ของ {0} มี {1}".format(n,eeven))

# if eodd == []:
#     print("e-oddของ {0} คือ 1".format(n))

if eeven == []:
    print("e-evenของ {0} คือ 1".format(n))
# Out:
# e-evenของ 280 คือ 1

# %% [markdown]
# <p style="margin-top: 0px;
#           margin-bottom: 50px;
#           text-align: center;
#           font-family: sans-serif;
#           font-size: 3rem;
#           letter-spacing: 0.15rem;
#           text-transform: uppercase;
#           color: #fff;
#           text-shadow: -4px 4px #ef3550,
#                -8px 8px #f48fb1,
#                -12px 12px #7e57c2,
#                -16px 16px #2196f3,
#                -20px 20px #26c6da,
#                -24px 24px #43a047,
#                -28px 28px #eeff41,
#                -32px 32px #f9a825,
#                -36px 36px #ff5722;">
#                square-free number
# </p>

# %%
n = int(input("Enter จำนวนนับนะจ๊ะ: "))
